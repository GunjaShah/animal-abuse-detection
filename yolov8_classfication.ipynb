# %%
# !yolo task=classify mode=train model=yolov8n-cls.pt data='splited_dataset' epochs=20 imgsz=128
# Out:
# Ultralytics YOLOv8.0.157  Python-3.10.11 torch-2.0.1+cpu CPU (Intel Core(TM) i7-10750H 2.60GHz)
# ...

# %%
# !yolo mode=predict model='runs/classify/train/weights/best.pt' source='test_videos/test_video.mp4'
# Out:
# Ultralytics YOLOv8.0.157  Python-3.10.11 torch-2.0.1+cpu CPU (Intel Core(TM) i7-10750H 2.60GHz)
# YOLOv8n-cls summary (fused): 73 layers, 1437442 parameters, 0 gradients, 3.3 GFLOPs
#
# video 1/1 (1/790) c:\DOCS\Advanced Computer Vision\Animal_abuse_classification\test_videos\test_video.mp4: 128x128 not_animal_abuse 0.61, animal_abuse 0.39, 12.0ms
# video 1/1 (2/790) c:\DOCS\Advanced Computer Vision\Animal_abuse_classification\test_videos\test_video.mp4: 128x128 not_animal_abuse 0.61, animal_abuse 0.39, 8.0ms
# video 1/1 (3/790) c:\DOCS\Advanced Computer Vision\Animal_abuse_classification\test_videos\test_video.mp4: 128x128 not_animal_abuse 0.61, animal_abuse 0.39, 6.0ms
# video 1/1 (4/790) c:\DOCS\Advanced Computer Vision\Animal_abuse_classification\test_videos\test_video.mp4: 128x128 not_animal_abuse 0.61, animal_abuse 0.39, 6.0ms
# ...
